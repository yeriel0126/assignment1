# %% [markdown]
# # LeetCode 225. Implement Stack using Queues

# %%
from collections import deque
class MyStack:
    def __init__(self):
        self.q = deque()

    def push(self, x: int) -> None:
        self.q.append(x)
        for _ in range(len(self.q) - 1):
            self.q.rotate(-1)

    def pop(self) -> int:
        return self.q.popleft()
        

    def top(self) -> int:
        return self.q[0]

    def empty(self) -> bool:
        if self.q:
            return False
        else:
            return True

# %% [markdown]
# # LeetCode 232. Implement Queue using Stacks

# %%
class MyQueue:
    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.__push_stack=[]
        self.__pop_stack=[]
        

    def push(self, x: int) -> None:
        """
        Push element x to the back of queue.
        """
        self.__push_stack.append(x)
        

    def pop(self) -> int:
        """
        Removes the element from in front of queue and returns that element.
        """
        if self.__pop_stack:
            return self.__pop_stack.pop()
        else:
            while self.__push_stack: # Move push_stack to pop_stack
                temp=self.__push_stack.pop() 
                self.__pop_stack.append(temp) 
            return self.__pop_stack.pop()
            
            
        
        

    def peek(self) -> int:
        
        """
        Get the front element.
        """
        if self.__pop_stack:
            return self.__pop_stack[-1]
        else:
            
            while self.__push_stack: # Move push_stack to pop_stack
                temp=self.__push_stack.pop()
                self.__pop_stack.append(temp)
            return self.__pop_stack[-1]
            
        

    def empty(self) -> bool:
        """
        Returns whether the queue is empty.
        """
        return False if self.__push_stack or self.__pop_stack else True

# %% [markdown]
# # 교재의 큐 연습문제

# %%
#1
class ListQueue:
	def __init__(self):
    	self.__queue = []
    
    def enqueue(self, item):
    	self.__queue.insert(0, item)
        
    def dequeue(self):
    	return self.__queue.pop()
        
    def front(self):
    	if self.__queue.is_empty():
        	return None
        else:
        	return self.__queue[len(self.__queue) - 1]
            
    def is_empty(self) -> bool:
    	return not bool(self.__queue)
        
    def dequeue_all(self):
    	self.__queue.clear()

# %%
#2
def is_in_set(string: String) -> bool:
	q = ListQueue()
    index = 0
    while string[index] != '$':
    	q.enqueue(string[index])
        index += 1
    index += 1
    while index < len(string):
    	if q.dequeue() != string[index]:
        	return False
        else:
        	index += 1
    return True

# %%
#3
def copy_linked_queue(a: LinkedQueue, b: LinkedQueue):
	b.dequeue_all()
    temp_queue = LinkedQueue()
    while not a.is_empty():
    	temp_queue.enqueue(a.dequeue())
    while not temp_queue.is_empty():
    	a.enqueue(temp_queue.front())
        b.enqueue(temp_queue.dequeue())

# %%
#4
def push(q1: LinkedQueue, q2: LinkedQueue, item):
	q2.dequeue_all()
	while not q1.is_empty():
    	q2.enqueue(q1.dequeue())
    q1.enqueue(item)
    while not q2.is_empty():
    	q1.enqueue(q2.dequeue())

def pop(q1: LinkedQueue, q2: LinkedQueue):
	q2.dequeue_all()
    count = 0
	while not q1.is_empty():
    	q2.enqueue(q1.dequeue())
        count += 1
    while _ in range(count - 1):
    	q1.enqueue(q2.dequeue())
    return q2.dequeue()

# %%
#5
def enqueue(s1: LinkedStack, s2: LinkedStack, item):
	s2.pop_all()
    while not s1.is_empty():
    	s2.push(s1.pop())
    s1.push(item)
    while not s2.is_empty():
    	s1.push(s2.pop())

def dequeue(s1: LinkedStack, s2: LinkedStack):
	s2.pop_all()
    while not s1.is_empty():
    	s2.push(s1.pop())
    ret_item = s2.pop()
    while not s2.is_empty():
    	s1.push(s2.pop())
    return ret_item

# %%
#6
enqueue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(1)이다. -> 수행 위치에 상관없이 enqueue()의 수행 시간은 Θ(1)이다.
dequeue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(1)이다. -> 수행 위치에 상관없이 dequeue()의 수행 시간은 Θ(1)이다.

# %%
#7
enqueue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(n)이다. -> enqueue()의 수행 시간은 최악의 경우를 고려해 Θ(n)이다.
dequeue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(n)이다. -> dequeue()의 수행 시간은 최악의 경우를 고려해 Θ(n)이다.

# %%
#8
class ListDeque:
	def __init__(self):
    	self.__queue = []
    
    def enqueue(self, item):
    	self.__queue.append(item)
    
    def dequeue(self):
    	return self.__queue.pop(0)
    
    def push(self, item):
    	self.__queue.insert(0, item)
    
    def pop(self):
    	return self.__queue.pop(len(self.__queue) - 1)
    
    def front(self):
    	if self.is_empty():
        	return None
        else:
        	return self.__queue[0]
    
    def rear(self):
    	if self.is_empty():
        	return None
    	else:
        	return self.__queue[len(self.__queue) - 1]
    
    def is_empty(self):
    	return not bool(self.__queue)
    
    def deque_all(self):
    	self.__queue.clear()
    
    def print_deque(self):
    	print("Dequeue from front:", end = ' ')
        for index in range(len(self.__queue)):
        	print(self.__queue[index], end = ' ')
        print()
